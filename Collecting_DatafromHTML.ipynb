# %%
from bs4 import BeautifulSoup 
from lxml import html
import requests
import pandas as pd
import numpy as np

# %%
html_source = "EVChargers.html"
with open(html_source, 'r', encoding='utf-8') as source: 
    tree = BeautifulSoup(source, 'html.parser')

# %%
data = []
for al in tree.select('a'):
    data.append(al.text)

# %%
link = []
for al in tree.select('a'):
    link.append(al.get('href'))

# %%
link
# Out:
# ['#main',
#  'https://www.facebook.com/evreporterpage/',
#  'https://twitter.com/evreporterin',
#  'https://www.youtube.com/channel/UChDzdDdUuzI2sKlvK_WxNsw',
#  'https://www.linkedin.com/company/evreporter/',
#  'https://evreporter.com/',
#  'https://evreporter.com/',
#  'https://www.jendamark.in/ev/',
#  'https://evreporter.com/',
#  'https://evreporter.com',
#  'https://evreporter.com/category/articles/',
#  'https://evreporter.com/category/start-up-stories/',
#  'https://evreporter.com/resources/',
#  'https://evreporter.com/category/learning-resources/',
#  'https://evreporter.com/magazines/',
#  'https://evreporter.com/policies/',
#  'https://evreporter.com/database/',
#  'https://evreporter.com/category/ev-news/',
#  'https://evreporter.com/business-listings/',
#  'https://evreporter.com/evreporter-events/',
#  'https://evreporter.com/our-services/',
#  'https://evreporter.com/contact-us/',
#  'https://evreporter.com/category/ev-resources/',
# ...
