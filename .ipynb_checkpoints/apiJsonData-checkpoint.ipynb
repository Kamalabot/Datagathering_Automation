# %%
import requests
import json
import time

# %%
#Initiating the session
scrape = requests.Session()
#Getting the first URL
entry = 'https://libraries.io/api/Pypi/requests?api_key=8'
api = '598f29e15e3a1e7ac5df0b0b43b67711'

# %%
#Initiating the session
scrape = requests.Session()
#Getting the first URL
entry = 'https://www.nseindia.com/api/equity-stockIndices?index=NIFTY%2050'

# %%
hugo = requests.get(entry).json()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 hugo = requests.get(entry).json()
#
# File /usr/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ...

# %%
libraries[2978]
# Out:
# {'download_count': 183280, 'project': 'braintree'}

# %%
for index,project in enumerate(libraries[:2]):
    makeUrl = f'https://libraries.io/api/Pypi/{project["project"]}?api_key=598f29e15e3a1e7ac5df0b0b43b67711'

    print(f'url : {makeUrl}')
    
    tempData = requests.get(makeUrl).json()
    tempDict = {};
    dataArry = ['name','dependent_repos_count','dependents_count','description','forks','keywords','stars','rank','repository_url','versions']
    for key in dataArry:
        tempDict[key] = tempData.get(key)
    print(tempDict)

    with open('myDataRev01.json','a') as outFile:
        json.dump(tempDict,outFile)

    print(f'the Index is {index} and project is {project}')    

    time.sleep(2)
# Out:
# url : https://libraries.io/api/Pypi/tensorflow-model-optimization?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 0 and project is {'download_count': 156569, 'project': 'tensorflow-model-optimization'}
# url : https://libraries.io/api/Pypi/econml?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 1 and project is {'download_count': 156517, 'project': 'econml'}
# url : https://libraries.io/api/Pypi/pandas-access?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 2 and project is {'download_count': 156474, 'project': 'pandas-access'}
# url : https://libraries.io/api/Pypi/alexapy?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 3 and project is {'download_count': 156397, 'project': 'alexapy'}
# url : https://libraries.io/api/Pypi/jaconv?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 4 and project is {'download_count': 156343, 'project': 'jaconv'}
# url : https://libraries.io/api/Pypi/hmsclient?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# ...

# %%
for index,project in enumerate(libraries[:2]):
    makeUrl = f'https://libraries.io/api/Pypi/{project["project"]}?api_key=598f29e15e3a1e7ac5df0b0b43b67711'

    print(f'url : {makeUrl}')
    
    tempData = requests.get(makeUrl).json()
    tempDict = {};
    dataArry = ['name','dependent_repos_count','dependents_count','description','forks','keywords','stars','rank','repository_url']
    for key in dataArry:
        tempDict[key] = tempData.get(key)
    print(tempDict)
# Out:
# url : https://libraries.io/api/Pypi/boto3?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# {'name': 'boto3', 'dependent_repos_count': 11545, 'dependents_count': 4680, 'description': 'The AWS SDK for Python', 'forks': 1639, 'keywords': ['aws', 'aws-sdk', 'cloud', 'cloud-management', 'python'], 'stars': 7495, 'rank': 27, 'repository_url': 'https://github.com/boto/boto3'}
# url : https://libraries.io/api/Pypi/setuptools?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# {'name': 'setuptools', 'dependent_repos_count': 28965, 'dependents_count': 7606, 'description': 'Easily download, build, install, upgrade, and uninstall Python packages', 'forks': 921, 'keywords': ['CPAN', 'PyPI', 'distutils', 'eggs', 'package', 'management'], 'stars': 1757, 'rank': 26, 'repository_url': 'https://github.com/pypa/setuptools'}

# %%
aryObj = []

for index,project in enumerate(libraries[:2]):
    makeUrl = f'https://libraries.io/api/Pypi/{project["project"]}?api_key=598f29e15e3a1e7ac5df0b0b43b67711'

    print(f'url : {makeUrl}')
    
    tempData = requests.get(makeUrl).json()
    tempDict = {};
    dataArry = ['name','dependent_repos_count','dependents_count','description','forks','keywords','stars','rank','repository_url']
    for key in dataArry:
        tempDict[key] = tempData.get(key)
    print(tempDict)
    aryObj.append(tempDict)
    print(f'the Index is {index} and project is {project}')    

    time.sleep(2)

with open('temp.json','a') as outFile:
    outFile.write(str(aryObj))
# Out:
# url : https://libraries.io/api/Pypi/boto3?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# {'name': 'boto3', 'dependent_repos_count': 11545, 'dependents_count': 4680, 'description': 'The AWS SDK for Python', 'forks': 1639, 'keywords': ['aws', 'aws-sdk', 'cloud', 'cloud-management', 'python'], 'stars': 7495, 'rank': 27, 'repository_url': 'https://github.com/boto/boto3'}
# the Index is 0 and project is {'download_count': 382074971, 'project': 'boto3'}
# url : https://libraries.io/api/Pypi/setuptools?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# {'name': 'setuptools', 'dependent_repos_count': 28965, 'dependents_count': 7606, 'description': 'Easily download, build, install, upgrade, and uninstall Python packages', 'forks': 921, 'keywords': ['CPAN', 'PyPI', 'distutils', 'eggs', 'package', 'management'], 'stars': 1757, 'rank': 26, 'repository_url': 'https://github.com/pypa/setuptools'}
# the Index is 1 and project is {'download_count': 284853880, 'project': 'setuptools'}

# %%
with open('myDataRev07.json','a') as outFile:
        outFile.write('[')

# %%
#Json.dump() works with the dict
for index,project in enumerate(libraries[4115:]):
    makeUrl = f'https://libraries.io/api/Pypi/{project["project"]}?api_key=598f29e15e3a1e7ac5df0b0b43b67711'

    print(f'url : {makeUrl}')
    
    tempData = requests.get(makeUrl).json()
    tempDict = {};
    dataArry = ['name','dependent_repos_count','dependents_count','description','forks','keywords','stars','rank','repository_url']
    for key in dataArry:
        tempDict[key] = tempData.get(key)

    with open('myDataRev07.json','a') as outFile:
        json.dump(tempDict,outFile)
        outFile.write(',')

    print(f'the Index is {index} and project is {project}')    

    time.sleep(2)
# Out:
# url : https://libraries.io/api/Pypi/prometheus-fastapi-instrumentator?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 0 and project is {'download_count': 89597, 'project': 'prometheus-fastapi-instrumentator'}
# url : https://libraries.io/api/Pypi/fake-factory?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 1 and project is {'download_count': 89594, 'project': 'fake-factory'}
# url : https://libraries.io/api/Pypi/pglast?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 2 and project is {'download_count': 89589, 'project': 'pglast'}
# url : https://libraries.io/api/Pypi/pyobjc-framework-mediaplayer?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 3 and project is {'download_count': 89562, 'project': 'pyobjc-framework-mediaplayer'}
# url : https://libraries.io/api/Pypi/pyobjc-framework-webkit?api_key=598f29e15e3a1e7ac5df0b0b43b67711
# the Index is 4 and project is {'download_count': 89546, 'project': 'pyobjc-framework-webkit'}
# ...

# %%
with open('myDataRev07.json','a') as outFile:
    outFile.write(']')
